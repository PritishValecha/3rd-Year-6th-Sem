# %%
import pandas as pd
import numpy as np
df=pd.read_csv("covid_vaccine_statewise.csv")
df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
df.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
df.drop(columns='Updated On', inplace=True)
df
# Out:
#             State  Total Doses Administered  Sessions   Sites   \
# 0           India                   48276.0    3455.0   2957.0
# 1           India                   58604.0    8532.0   4954.0
# 2           India                   99449.0   13611.0   6583.0
# 3           India                  195525.0   17855.0   7951.0
# 4           India                  251280.0   25472.0  10504.0
# ...           ...                       ...       ...      ...
# 7840  West Bengal                       NaN       NaN      NaN
# 7841  West Bengal                       NaN       NaN      NaN
# 7842  West Bengal                       NaN       NaN      NaN
# 7843  West Bengal                       NaN       NaN      NaN
# 7844  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# 0                     48276.0                       0.0
# 1                     58604.0                       0.0
# ...

# %%
df.drop(columns='Sessions', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   First Dose Administered  \
# 0           India                   48276.0   2957.0                  48276.0
# 1           India                   58604.0   4954.0                  58604.0
# 2           India                   99449.0   6583.0                  99449.0
# 3           India                  195525.0   7951.0                 195525.0
# 4           India                  251280.0  10504.0                 251280.0
# ...           ...                       ...      ...                      ...
# 7840  West Bengal                       NaN      NaN                      NaN
# 7841  West Bengal                       NaN      NaN                      NaN
# 7842  West Bengal                       NaN      NaN                      NaN
# 7843  West Bengal                       NaN      NaN                      NaN
# 7844  West Bengal                       NaN      NaN                      NaN
#
# ...

# %%
df.drop(columns='First Dose Administered', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Second Dose Administered  Male (Doses Administered)  \
# 0                          0.0                        NaN
# 1                          0.0                        NaN
# 2                          0.0                        NaN
# 3                          0.0                        NaN
# ...

# %%
df.drop(columns='Second Dose Administered', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='Transgender (Doses Administered)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='CoviShield (Doses Administered)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='Sputnik V (Doses Administered)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='AEFI', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='18-44 Years (Doses Administered)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='45-60 Years (Doses Administered)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='60+ Years (Doses Administered)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='18-44 Years(Individuals Vaccinated)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='45-60 Years(Individuals Vaccinated)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='60+ Years(Individuals Vaccinated)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='Male(Individuals Vaccinated)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='Female(Individuals Vaccinated)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.drop(columns='Transgender(Individuals Vaccinated)', inplace=True)
df
# Out:
#             State  Total Doses Administered   Sites   \
# 0           India                   48276.0   2957.0
# 1           India                   58604.0   4954.0
# 2           India                   99449.0   6583.0
# 3           India                  195525.0   7951.0
# 4           India                  251280.0  10504.0
# ...           ...                       ...      ...
# 7840  West Bengal                       NaN      NaN
# 7841  West Bengal                       NaN      NaN
# 7842  West Bengal                       NaN      NaN
# 7843  West Bengal                       NaN      NaN
# 7844  West Bengal                       NaN      NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# ...

# %%
df.isnull().sum()
# Out:
# State                               0
# Total Doses Administered          224
#  Sites                            224
# Male (Doses Administered)         384
# Female (Doses Administered)       384
#  Covaxin (Doses Administered)     224
# Total Individuals Vaccinated     1926
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#                             State  Total Doses Administered   Sites   \
# 212   Andaman and Nicobar Islands                      23.0      2.0
# 213   Andaman and Nicobar Islands                      23.0      2.0
# 214   Andaman and Nicobar Islands                      42.0      2.0
# 215   Andaman and Nicobar Islands                      89.0      2.0
# 216   Andaman and Nicobar Islands                     124.0      3.0
# ...                           ...                       ...      ...
# 7788                  West Bengal                19010947.0    732.0
# 7789                  West Bengal                19349842.0   2645.0
# 7790                  West Bengal                19667535.0   2390.0
# 7791                  West Bengal                20022881.0   2511.0
# 7792                  West Bengal                20352923.0   2260.0
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 212                        12.0                         11.0
# ...
